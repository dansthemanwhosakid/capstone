# %% [markdown]
# # Notebook 2: Data Scraping
#
# In order to supplement the combined movie dialogue and quotes dataframe, I will create a `movie_info` dataframe that has the following:
#
# |Feature|Type|Description|
# |---|---|---|
# |**original_title**|string|Original movie title from the `mov_combo` dataframe|
# |**imdb_title**|string|Official IMDb movie title|
# |**imdb_url**|string|Movie's IMDb url|
# |**genre**|list|Movie's genre(s)|
# |**pic_url**|string|Movie's promotional picture|
#
# Afterwards, the `movie_info` and `mov_combo` dataframes will be combined and cleaned to create a `mov_combo_final` dataframe that has the following:
#
# |Feature|Type|Description|
# |---|---|---|
# |**imdb_title**|string|Official IMDb movie title|
# |**character**|string|Movie character|
# |**text**|string|Movie character lines|
# |**tokenized_text**|list|Movie character lines split into individual words|
# |**word_count**|integer|Text word count|
# |**vader**|dictionary|Sentiment analysis score|
# |**genre**|list|Movie's genre(s)|
# |**imdb_url**|string|Movie's IMDb url|
# |**pic_url**|string|Movie's promotional picture|

# %%
mov_combo_final.head(1)
# Out:
#                           imdb_title  character  \
# 0  10 Things I Hate About You (1999)  bartender
#
#                                      text  \
# 0  What can I get you? You forgot to pay!
#
#                                    tokenized_text  word_count  \
# 0  [What, can, I, get, you, You, forgot, to, pay]           9
#
#                                                vader  \
# 0  {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'comp...
#
#                       genre                               imdb_url  \
# 0  [Comedy, Drama, Romance]  https://www.imdb.com/title/tt0147800/
#
#                                              pic_url
# 0  https://m.media-amazon.com/images/M/MV5BMmVhZj...

# %%
import pandas as pd
import re
import os
import time
import requests, sys, webbrowser, bs4
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import pickle

# %%
mov_combo = pd.read_pickle('../data/mov_combo.pkl')
mov_combo.head(3)
# Out:
#                         title          character  \
# 0  10 things i hate about you          bartender
# 1  10 things i hate about you             bianca
# 2  10 things i hate about you  bianca and walter
#
#                                                 text  \
# 0             What can I get you? You forgot to pay!
# 1  Did you change your hair? You might wanna thin...
# 2          The sound of a fifteen-year-old in labor.
#
#                                       tokenized_text  word_count  \
# 0     [What, can, I, get, you, You, forgot, to, pay]           9
# 1  [Did, you, change, your, hair, You, might, wan...        1295
# 2  [The, sound, of, a, fifteen, year, old, in, la...           9
#
#                                                vader
# 0  {'neg': 0.195, 'neu': 0.805, 'pos': 0.0, 'comp...
# 1  {'neg': 0.108, 'neu': 0.726, 'pos': 0.166, 'co...
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...

# %% [markdown]
# Grabbing the unique movie titles in the `mov_combo` dataframe.

# %%
unique_titles = list(mov_combo['title'].unique())
len(unique_titles)
# Out:
# 1075

# %% [markdown]
# There are 1075 unique movies.

# %% [markdown]
# Creating the `movie_info` dataframe.

# %%
movie_info = pd.DataFrame({'original_title':unique_titles,
                           'imdb_title': 'none',
                           'imdb_url': 'none',
                           'genre': 'none',
                           'pic_url': 'none',
                           'info_all_collected':0
                          })
movie_info.head()
# Out:
#                original_title imdb_title imdb_url genre pic_url  \
# 0  10 things i hate about you       none     none  none    none
# 1  1492: conquest of paradise       none     none  none    none
# 2                  15 minutes       none     none  none    none
# 3       2001: a space odyssey       none     none  none    none
# 4                     48 hrs.       none     none  none    none
#
#    info_all_collected
# 0                   0
# 1                   0
# 2                   0
# 3                   0
# 4                   0

# %% [markdown]
# Creating the movie scraper function, `movie_info_update()`. The following function inputs the original movie title plus 'movie IMDb' into Google search, then visits the first search result, which is likely to be the IMDb url associated with the movie. The title, genre, and picture urls are then scraped.
#
# If there is an error in obtaining the columns `imdb_title`, `imdb_url`, `genre`, `pic_url`, then `info_all_collected` will stay as 0. If all the information is collected then `info_all_collected` will be marked as 1.

# %%
def movie_info_update(df, row_index, original_title):
    
    print(f'Processing {original_title}...')
    # input movie title
    movie_title = str(original_title)
    
    # replace spaces with pluses for google search
    query = movie_title.replace(" ","+")
    
    # Replace '&' with 'and'
    query = movie_title.replace("&","and")

    # selects the first url from google search, which is IMDB
    try:
        res = requests.get('https://google.com/search?q='+query+'+movie+imdb')
        soup = bs4.BeautifulSoup(res.text, 'html.parser')
        linkElements = soup.select('.r a')
    
    # Grab movie's imdb url
        movie_imdb_link = linkElements[0].get('href').replace('/url?q=','').split('&')[0]
    
    except:
        print("Failed to obtain IMDb url")
        movie_imdb_link = np.NaN
        df.at[row_index,'info_all_collected'] = 0
    
    # wait for 5 seconds until next request
    time.sleep(5)
    
    # Go to the movie's imdb page
    try:
        res = requests.get(movie_imdb_link)
        soup = bs4.BeautifulSoup(res.text, 'lxml')
    except:
        print("Failed to request IMDb url")
        df.at[row_index,'info_all_collected'] = 0
    
    # Get movie's IMDB title
    try:
        title = soup.find('title').text.replace(" - IMDb","")
    except:
        title = np.NaN
        df.at[row_index,'info_all_collected'] = 0
    
    # Find movie's genre(s)
    try:
        for_genre = soup.find_all('div', {'class':'subtext'})
        genres = [g.text for g in for_genre[0].find_all('a')][:-1]
        genres = ",".join(genres)
    except:
        genres = np.NaN
        df.at[row_index,'info_all_collected'] = 0
    
    # Grab movie's picture URL:
    try:
        for_pic = soup.find('script', {'type':'application/ld+json'}).text
        movie_pic = re.findall("https:\/\/m.media[^\"]*",for_pic)[0]
    except:
        movie_pic = np.NaN
        df.at[row_index,'info_all_collected'] = 0
    
    # Updating imdb title, imdb url, genre, pic url
    df.at[row_index,'imdb_title'] = title
    df.at[row_index,'imdb_url'] = movie_imdb_link
    df.at[row_index,'genre'] = genres
    df.at[row_index,'pic_url'] = movie_pic
    
    # Changing info_all_collected to 1 if there are no nulls 
    df.loc[~df.isnull().any(axis=1),'info_all_collected'] = 1

# %%
# %%time
for row_index, title in movie_info['original_title'].iteritems():
    movie_info_update(movie_info, row_index, title)
# Out:
# Processing 10 things i hate about you...
# Processing 1492: conquest of paradise...
# Processing 15 minutes...
# Processing 2001: a space odyssey...
# Processing 48 hrs....
# Processing 8mm...
# Processing a bucket of blood...
# Processing a clockwork orange...
# Processing a dry white season...
# Processing a few good men...
# Processing a hard day's night...
# Processing a nightmare on elm street...
# Processing a nightmare on elm street 3: dream warriors...
# Processing a nightmare on elm street 4: the dream master...
# Processing a nightmare on elm street part 2: freddy's revenge...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing a nightmare on elm street: the dream child...
# Processing a perfect world...
# Processing a serious man...
# Processing a walk to remember...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing above the law...
# Processing absolute power...
# Processing ace ventura pet detective...
# Processing adaptation...
# Processing affliction...
# Processing after...
# Processing after school special...
# Processing agnes of god...
# Processing air force one...
# Processing airplane...
# Processing airplane 2 the sequel...
# Processing airplane ii: the sequel...
# Processing airplane!...
# Processing aladdin...
# Processing ali...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing alien...
# Processing alien 3...
# Processing alien nation...
# Processing alien resurrection...
# Processing alien vs...
# Processing aliens...
# Processing all about eve...
# Processing all about steve...
# Processing all the king's men...
# Processing all the president's men...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing almost famous...
# Processing alone in the dark...
# Processing amadeus...
# Processing amelia...
# Processing american beauty...
# Processing american gangster...
# Processing american graffiti...
# Processing american history x...
# Processing american madness...
# Processing american outlaws...
# Processing american pie...
# Processing american psycho...
# Processing american shaolin king of kickboxers ii...
# Processing american splendor...
# Processing american werewolf in london...
# Processing an american werewolf in london...
# Processing an american werewolf in paris...
# Processing an education...
# Processing an officer and a gentleman...
# Processing analyze that...
# Processing analyze this...
# Processing anastasia...
# Processing angel eyes...
# Processing angels & demons...
# Processing annie hall...
# Processing antitrust...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing antz...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing apocalypse now...
# Processing apt pupil...
# Processing arcade...
# Processing arctic blue...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing armageddon...
# Processing army of darkness...
# Processing as good as it gets...
# Processing assassins...
# Processing asylum...
# Processing at first sight...
# Processing austin powers   international man of mystery...
# Processing austin powers   the spy who shagged me...
# Processing austin powers: international man of mystery...
# Processing autumn in new york...
# Processing avatar...
# Processing avventura, l' (the adventure)...
# Processing awakenings...
# Processing babel...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing bachelor party...
# Processing back to the future...
# Processing backdraft...
# Processing bad boys...
# Processing bad day at black rock...
# Processing bad lieutenant...
# Processing bad santa...
# Processing badlands...
# Processing bamboozled...
# Processing barry lyndon...
# Processing barton fink...
# Processing basic...
# Processing basic instinct...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing basquiat...
# Processing batman...
# Processing batman 2...
# Processing batman and robin...
# Processing batman forever...
# Processing batman returns...
# Processing battle los angeles...
# Processing bean...
# Processing beavis and butt head do america...
# Processing beavis and butt-head do america...
# Processing beetle juice...
# Processing being human...
# Processing being john malkovich...
# Processing being there...
# Processing beloved...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing big...
# Processing big fish...
# Processing birthday girl...
# Processing black rain...
# Processing black snake moan...
# Processing blade...
# Processing blade ii...
# Processing blade runner...
# Processing blade trinity...
# Processing blast from the past...
# Processing blood simple...
# Processing bloodmoon...
# Processing blow...
# Processing blue velvet...
# Processing bodies, rest & motion...
# Processing body heat...
# Processing body of evidence...
# Processing bodyguard...
# Processing bones...
# Processing bonfire of the vanities...
# Processing bonnie and clyde...
# Processing boogie nights...
# Processing book of shadows: blair witch 2...
# Processing boondock saints 2 all saints day...
# Processing bottle rocket...
# Processing bound...
# Processing braveheart...
# Processing brazil...
# Processing break...
# Processing breakdown...
# Processing brick...
# Processing bridesmaids...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing bringing out the dead...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing broadcast news...
# Processing broken arrow...
# Processing broken embraces...
# Processing bruce almighty...
# Processing buffy the vampire slayer...
# Processing bull durham...
# Processing buried...
# Processing burlesque...
# Processing burn after reading...
# Processing cable guy...
# Processing capote...
# Processing casablanca...
# Processing casino...
# Processing cast away...
# Processing catch me if you can...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing catwoman...
# Processing cellular...
# Processing changeling...
# Processing chaos...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing charade...
# Processing charlie's angels...
# Processing chasing amy...
# Processing cherry falls...
# Processing chill factor...
# Processing chinatown...
# Processing cinema paradiso...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing cirque du freak the vampire's assistant...
# Processing citizen kane...
# Processing city of joy...
# Processing clash of the titans...
# Processing clerks...
# Processing cliffhanger...
# Processing cobb...
# Processing code of silence...
# Processing cold mountain...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing collateral...
# Processing collateral damage...
# Processing confessions of a dangerous mind...
# Processing confidence...
# Processing conspiracy theory...
# Processing constantine...
# Processing contact...
# Processing cool hand luke...
# Processing copycat...
# Processing coraline...
# Processing cradle 2 the grave...
# Processing crank...
# Processing crash...
# Processing crazy love...
# Processing crazylove...
# Processing crime spree...
# Processing crouching tiger, hidden dragon...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing croupier...
# Processing cruel intentions...
# Processing crying game...
# Processing cube...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing custody...
# Processing dances with wolves...
# Processing dark angel...
# Processing dark city...
# Processing dark star...
# Processing darkman...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing date night...
# Processing dave...
# Processing dawn of the dead...
# Processing day of the dead...
# Processing days of heaven...
# Processing dead poets society...
# Processing death at a funeral...
# Processing death to smoochy...
# Processing deception...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing deep cover...
# Processing deep rising...
# Processing defiance...
# Processing demolition man...
# Processing detroit rock city...
# Processing devil in a blue dress...
# Processing devil's advocate...
# Processing die hard...
# Processing disturbia...
# Processing do the right thing...
# Processing dog day afternoon...
# Processing dogma...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing domino...
# Processing donnie brasco...
# Processing donnie darko...
# Processing double indemnity...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing drag me to hell...
# Processing dragon slayer...
# Processing dragonslayer...
# Processing drive angry...
# Processing drop dead gorgeous...
# Processing duck soup...
# Processing dumb and dumber...
# Processing dumb and dumberer: when harry met lloyd...
# Processing dune...
# Processing e...
# Processing eagle eye...
# Processing eastern promises...
# Processing ed tv...
# Processing ed wood...
# Processing edtv...
# Processing edward scissorhands...
# Processing eight legged freaks...
# Processing el mariachi...
# Processing election...
# Processing elizabeth the golden age...
# Processing enemy of the state...
# Processing entrapment...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing erik the viking...
# Processing erin brockovich...
# Processing escape from l...
# Processing escape from new york...
# Processing escape from the planet of the apes...
# Processing eternal sunshine of the spotless mind...
# Processing even cowgirls get the blues...
# Processing event horizon...
# Processing evil dead...
# Processing evil dead 2: dead before dawn...
# Processing evil dead ii dead by dawn...
# Processing excalibur...
# Processing existenz...
# Processing extract...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing face off...
# Processing face/off...
# Processing fair game...
# Processing fantastic four...
# Processing fantastic mr fox...
# Processing fantastic voyage...
# Processing fargo...
# Processing fast times at ridgemont high...
# Processing fatal instinct...
# Processing fear and loathing in las vegas...
# Processing feast...
# Processing ferris bueller's day off...
# Processing fight club...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing final destination...
# Processing final destination 2...
# Processing finding nemo...
# Processing five easy pieces...
# Processing five feet high and rising...
# Processing fletch...
# Processing forrest gump...
# Processing four feathers...
# Processing four rooms...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing fracture...
# Processing frances...
# Processing frankenstein...
# Processing freddy vs...
# Processing frequency...
# Processing friday the 13th...
# Processing friday the 13th part iii...
# Processing friday the 13th part viii jason takes manhattan...
# Processing from dusk till dawn...
# Processing frozen...
# Processing frozen river...
# Processing funny people...
# Processing g...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing g.i. jane...
# Processing galaxy quest...
# Processing game 6...
# Processing gamer...
# Processing gandhi...
# Processing gang related...
# Processing gangs of new york...
# Processing gattaca...
# Processing george washington...
# Processing get carter...
# Processing get low...
# Processing get shorty...
# Processing ghost...
# Processing ghost rider...
# Processing ghost ship...
# Processing ghost world...
# Processing ghostbusters...
# Processing ghostbusters 2...
# Processing ghostbusters ii...
# Processing ginger snaps...
# Processing gladiator...
# Processing glengarry glen gross...
# Processing glengarry glen ross...
# Processing go...
# Processing godfather...
# Processing godfather part ii...
# Processing gods and monsters...
# Processing godzilla...
# Processing gone in 60 seconds...
# Processing gone in sixty seconds...
# Processing good will hunting...
# Processing goodfellas...
# Processing gothika...
# Processing gran torino...
# Processing grand hotel...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing grand theft parsons...
# Processing gremlins...
# Processing gremlins 2...
# Processing grosse point blank...
# Processing grosse pointe blank...
# Processing groundhog day...
# Processing hackers...
# Processing halloween...
# Processing halloween 4: the return of michael myers...
# Processing halloween h20: 20 years later...
# Processing halloween iii: season of the witch...
# Processing halloween the curse of michael myers...
# Processing halloween: the curse of michael myers...
# Processing hancock...
# Processing hanna...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing hannah and her sisters...
# Processing hannibal...
# Processing happy birthday, wanda june...
# Processing happy campers...
# Processing hard rain...
# Processing hard to kill...
# Processing hardcore...
# Processing harold and kumar go to white castle...
# Processing harold and maude...
# Processing harvey...
# Processing he's just not that into you...
# Processing heat...
# Processing heathers...
# Processing heavenly creatures...
# Processing heavy metal...
# Processing heist...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing hellbound hellraiser ii...
# Processing hellbound: hellraiser ii...
# Processing hellboy...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing hellboy 2 the golden army...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing hellraiser...
# Processing hellraiser 3 hell on earth...
# Processing hellraiser deader...
# Processing hellraiser hellseeker...
# Processing hellraiser iii: hell on earth...
# Processing henry fool...
# Processing hero...
# Processing hider in the house...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing high fidelity...
# Processing highlander...
# Processing highlander endgame...
# Processing highlander iii: the sorcerer...
# Processing his girl friday...
# Processing hollow man...
# Processing honeydripper...
# Processing hope and glory...
# Processing hostage...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing hot tub time machine...
# Processing hotel rwanda...
# Processing house of 1000 corpses...
# Processing house of the damned...
# Processing house on haunted hill...
# Processing how to train your dragon...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing hudson hawk...
# Processing human nature...
# Processing i am legend...
# Processing i am number four...
# Processing i am sam...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing i love you phillip morris...
# Processing i still know what you did last summer...
# Processing i walked with a zombie...
# Processing i'll do anything...
# Processing i, robot...
# Processing in the loop...
# Processing independence day...
# Processing indiana jones and the last crusade...
# Processing indiana jones and the raiders of the lost ark...
# Processing indiana jones and the temple of doom...
# Processing indiana jones iv...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing inglourious basterds...
# Processing innerspace...
# Processing insomnia...
# Processing interview with the vampire...
# Processing interview with the vampire: the vampire chronicles...
# Processing into the wild...
# Processing intolerable cruelty...
# Processing invaders from mars...
# Processing inventing the abbotts...
# Processing isle of the dead...
# Processing it happened one night...
# Processing it's a wonderful life...
# Processing it's complicated...
# Processing jackie brown...
# Processing jacob's ladder...
# Processing jason goes to hell: the final friday...
# Processing jason lives: friday the 13th part vi...
# Processing jason x...
# Processing jaws...
# Processing jaws 2...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing jaws 3-d...
# Processing jaws: the revenge...
# Processing jay and silent bob strike back...
# Processing jennifer eight...
# Processing jennifer's body...
# Processing jerry maguire...
# Processing jfk...
# Processing jimmy and judy...
# Processing john q...
# Processing juno...
# Processing jurassic park...
# Processing jurassic park iii...
# Processing jurassic park the lost world...
# Processing kafka...
# Processing kalifornia...
# Processing kate & leopold...
# Processing kids...
# Processing kill bill volume 1 & 2...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing killing zoe...
# Processing king kong...
# Processing klute...
# Processing knight moves...
# Processing kramer vs kramer...
# Processing krull...
# Processing kundun...
# Processing kung fu panda...
# Processing l...
# Processing l'avventura...
# Processing la battaglia di algeri...
# Processing labor of love...
# Processing labyrinth...
# Processing lake placid...
# Processing land of the dead...
# Processing last chance harvey...
# Processing law abiding citizen...
# Processing le grand bleu...
# Processing leaving las vegas...
# Processing legally blonde...
# Processing legend...
# Processing legion...
# Processing leon...
# Processing leviathan...
# Processing liar liar...
# Processing life...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing life as a house...
# Processing light sleeper...
# Processing little athens...
# Processing little nicky...
# Processing living in oblivion...
# Processing lock, stock and two smoking barrels...
# Processing logan's run...
# Processing lone star...
# Processing lord of illusions...
# Processing lord of the rings return of the king...
# Processing lord of the rings the two towers...
# Processing lord of war...
# Processing lost highway...
# Processing lost horizon...
# Processing lost in space...
# Processing lost in translation...
# Processing lost souls...
# Processing love & basketball...
# Processing love and basketball...
# Processing lΘon...
# Processing made...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing magnolia...
# Processing major league...
# Processing malcolm x...
# Processing malibu's most wanted...
# Processing man in the iron mask...
# Processing man on fire...
# Processing man on the moon...
# Processing man trouble...
# Processing manhunt...
# Processing manhunter...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing maniac...
# Processing margot at the wedding...
# Processing mariachi, el...
# Processing marley & me...
# Processing marty...
# Processing mash...
# Processing max payne...
# Processing meet joe black...
# Processing meet john doe...
# Processing megamind...
# Processing memento...
# Processing men in black...
# Processing metro...
# Processing metropolis...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing miami vice...
# Processing midnight cowboy...
# Processing midnight express...
# Processing mighty morphin power rangers...
# Processing mighty morphin power rangers the movie...
# Processing milk...
# Processing miller's crossing...
# Processing mimic...
# Processing mini's first time...
# Processing minority report...
# Processing mirrors...
# Processing misery...
# Processing mission impossible...
# Processing mission impossible ii...
# Processing mission to mars...
# Processing mobsters...
# Processing monkeybone...
# Processing monty python and the holy grail...
# Processing moon...
# Processing moonstruck...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing mr blandings builds his dream house...
# Processing mr brooks...
# Processing mr deeds goes to town...
# Processing mrs...
# Processing mrs brown...
# Processing mulholland drive...
# Processing mumford...
# Processing murderland...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing music of the heart...
# Processing my best friend's wedding...
# Processing my girl...
# Processing my girl 2...
# Processing my mother dreams the satan's disciples in new york...
# Processing mystery men...
# Processing mystery of the wax museum...
# Processing napoleon...
# Processing nashville...
# Processing natural born killers...
# Processing neuromancer...
# Processing never been kissed...
# Processing new nightmare...
# Processing new york minute...
# Processing newsies...
# Processing next...
# Processing next friday...
# Processing nick of time...
# Processing night at the roxbury...
# Processing nightbreed...
# Processing nightmare on elm street the final chapter...
# Processing ninja assassin...
# Processing ninotchka...
# Processing nixon...
# Processing no country for old men...
# Processing nothing but a man...
# Processing notting hill...
# Processing nuovo cinema paradiso...
# Processing nurse betty...
# Processing o brother where art thou%3f...
# Processing o brother, where art thou?...
# Processing observe and report...
# Processing obsessed...
# Processing ocean's eleven...
# Processing ocean's twelve...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing office space...
# Processing on the waterfront...
# Processing one flew over the cuckoo's nest...
# Processing only you...
# Processing ordinary people...
# Processing orgy of the dead...
# Processing orphan...
# Processing out of sight...
# Processing panic room...
# Processing panther...
# Processing pearl harbor...
# Processing peeping tom...
# Processing peggy sue got married...
# Processing perfect creature...
# Processing pet sematary...
# Processing pet sematary ii...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing petulia...
# Processing philadelphia...
# Processing phone booth...
# Processing pi...
# Processing pineapple express...
# Processing pirates of the caribbean...
# Processing pirates of the caribbean dead man's chest...
# Processing pitch black...
# Processing plastic man...
# Processing platinum blonde...
# Processing platoon...
# Processing playback...
# Processing pleasantville...
# Processing point break...
# Processing precious...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing predator...
# Processing pretty woman...
# Processing psycho...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing public enemies...
# Processing pulp fiction...
# Processing punch drunk love...
# Processing punch-drunk love...
# Processing purple rain...
# Processing quantum project...
# Processing queen of the damned...
# Processing quills...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing rachel getting married...
# Processing raging bull...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing raising arizona...
# Processing rambling rose...
# Processing rambo first blood ii the mission...
# Processing rambo: first blood part ii...
# Processing real genius...
# Processing rear window...
# Processing rebel without a cause...
# Processing red planet...
# Processing red white black & blue...
# Processing reindeer games...
# Processing remember me...
# Processing repo man...
# Processing reservoir dogs...
# Processing resident evil...
# Processing return of the apes...
# Processing revolutionary road...
# Processing ringu...
# Processing rko 281...
# Processing robin hood prince of thieves...
# Processing rocknrolla...
# Processing rocky...
# Processing romeo & juliet...
# Processing romeo and juliet...
# Processing ronin...
# Processing roughshod...
# Processing route 9...
# Processing runaway bride...
# Processing rush hour...
# Processing rush hour 2...
# Processing rushmore...
# Processing s...
# Processing salt of the earth...
# Processing save the last dance...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing saving private ryan...
# Processing saw...
# Processing scarface...
# Processing scary movie 2...
# Processing schindler's list...
# Processing scream...
# Processing scream 2...
# Processing scream 3...
# Processing se7en...
# Processing semi pro...
# Processing sense and sensibility...
# Processing serenity...
# Processing serial mom...
# Processing seven...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing seven days to live...
# Processing sex and the city...
# Processing sex, lies and videotape...
# Processing sexual life...
# Processing shakespeare in love...
# Processing shallow grave...
# Processing shampoo...
# Processing she's out of my league...
# Processing sherlock holmes...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing shivers...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing shock treatment...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing shrek...
# Processing sideways...
# Processing signs...
# Processing silence of the lambs...
# Processing silver bullet...
# Processing silverado...
# Processing simone...
# Processing sister act...
# Processing slash...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing sleepless in seattle...
# Processing sleepy hollow...
# Processing sling blade...
# Processing slither...
# Processing slumdog millionaire...
# Processing smoke...
# Processing smokey and the bandit...
# Processing smokin' aces...
# Processing snatch...
# Processing snow falling on cedars...
# Processing so i married an axe murderer...
# Processing solaris...
# Processing soldier...
# Processing some like it hot...
# Processing someone to watch over me...
# Processing something's gotta give...
# Processing sounder...
# Processing south park...
# Processing south park: bigger longer & uncut...
# Processing spacejacked...
# Processing spanglish...
# Processing spare me...
# Processing spartan...
# Processing speed racer...
# Processing sphere...
# Processing spider man...
# Processing spider-man...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing stalag 17...
# Processing star trek...
# Processing star trek first contact...
# Processing star trek generations...
# Processing star trek ii the wrath of khan...
# Processing star trek iii: the search for spock...
# Processing star trek iv: the voyage home...
# Processing star trek nemesis...
# Processing star trek the motion picture...
# Processing star trek v: the final frontier...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing star trek vi: the undiscovered country...
# Processing star trek: insurrection...
# Processing star trek: the wrath of khan...
# Processing star wars...
# Processing star wars a new hope...
# Processing star wars attack of the clones...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing star wars return of the jedi...
# Processing star wars revenge of the sith...
# Processing star wars the empire strikes back...
# Processing star wars the phantom menace...
# Processing star wars: episode vi - return of the jedi...
# Processing starman...
# Processing starship troopers...
# Processing state and main...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing station west...
# Processing stepmom...
# Processing stir of echoes...
# Processing storytelling...
# Processing strange days...
# Processing strangers on a train...
# Processing stranglehold...
# Processing suburbia...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing sucker the vampire...
# Processing sugar...
# Processing sugar & spice...
# Processing sugar and spice...
# Processing sunset blvd...
# Processing sunshine cleaning...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing superbad...
# Processing supergirl...
# Processing superman...
# Processing superman ii...
# Processing superman iii...
# Processing superman iv: the quest for peace...
# Processing superman: man of steel...
# Processing suspect zero...
# Processing sweet smell of success...
# Processing swingers...
# Processing swordfish...
# Processing synecdoche, new york...
# Processing taking lives...
# Processing taking sides...
# Processing talented mr...
# Processing tall in the saddle...
# Processing taxi driver...
# Processing terminator...
# Processing terminator 2 judgement day...
# Processing terminator 2: 3-d battle across time...
# Processing terminator 2: judgment day...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing terminator 2: judgment day - omitted scenes...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing terminator salvation...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the abyss...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the addams family...
# Processing the adjustment bureau...
# Processing the adventures of buckaroo banzai across the 8th dimension...
# Processing the adventures of buckaroo banzai across the eighth dimension...
# Processing the adventures of ford fairlane...
# Processing the american president...
# Processing the anniversary party...
# Processing the apartment...
# Processing the assignment...
# Processing the atomic submarine...
# Processing the avengers...
# Processing the bachelor party...
# Processing the battle of algiers...
# Processing the battle of shaker heights...
# Processing the beach...
# Processing the believer...
# Processing the big blue...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the big lebowski...
# Processing the big white...
# Processing the birds...
# Processing the black dahlia...
# Processing the blast from the past...
# Processing the body snatcher...
# Processing the book of eli...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the boondock saints...
# Processing the bounty hunter...
# Processing the bourne identity...
# Processing the bourne supremacy...
# Processing the bourne ultimatum...
# Processing the breakfast club...
# Processing the bridges of madison county...
# Processing the brothers bloom...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the butterfly effect...
# Processing the cell...
# Processing the chronicles of narnia the lion witch and the wardrobe...
# Processing the cider house rules...
# Processing the cincinnati kid...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the cooler...
# Processing the crow...
# Processing the crow city of angels...
# Processing the crow salvation...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the curious case of benjamin button...
# Processing the curse...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the curse of the cat people...
# Processing the damned united...
# Processing the day the clown cried...
# Processing the day the earth stood still...
# Processing the deer hunter...
# Processing the departed...
# Processing the devil and daniel webster...
# Processing the distinguished gentleman...
# Processing the doors...
# Processing the elephant man...
# Processing the english patient...
# Processing the exorcist...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the fabulous baker boys...
# Processing the family man...
# Processing the fifth element...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the fisher king...
# Processing the flintstones...
# Processing the french connection...
# Processing the fugitive...
# Processing the game...
# Processing the getaway...
# Processing the ghost and the darkness...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the good girl...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the goonies 2...
# Processing the graduate...
# Processing the grapes of wrath...
# Processing the green mile...
# Processing the grifters...
# Processing the grudge...
# Processing the hangover...
# Processing the haunting...
# Processing the hebrew hammer...
# Processing the hitchhiker's guide to the galaxy...
# Processing the horse whisperer...
# Processing the hospital...
# Processing the hudsucker proxy...
# Processing the hustler...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the ice storm...
# Processing the imaginarium of doctor parnassus...
# Processing the incredibles...
# Processing the insider...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the invention of lying...
# Processing the island...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the italian job...
# Processing the jacket...
# Processing the jazz singer...
# Processing the king of comedy...
# Processing the king's speech...
# Processing the kingdom...
# Processing the ladykillers...
# Processing the last boy scout...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the last flight...
# Processing the last of the mohicans...
# Processing the last samurai...
# Processing the last station...
# Processing the leopard man...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the life of david gale...
# Processing the limey...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the long kiss goodnight...
# Processing the lord of the rings fellowship of the ring...
# Processing the losers...
# Processing the lost boys...
# Processing the lost son...
# Processing the lost world: jurassic park...
# Processing the magic toyshop...
# Processing the majestic...
# Processing the majestic (the bijou)...
# Processing the man who knew too much...
# Processing the man who wasn't there...
# Processing the manchurian candidate...
# Processing the mask...
# Processing the matrix...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the matrix reloaded...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the mechanic...
# Processing the men who stare at goats...
# Processing the messenger...
# Processing the miracle worker...
# Processing the mummy...
# Processing the next three days...
# Processing the night of the hunter...
# Processing the nightmare before christmas...
# Processing the nines...
# Processing the other boleyn girl...
# Processing the pacifier...
# Processing the patriot...
# Processing the pianist...
# Processing the piano...
# Processing the planet of the apes...
# Processing the ploughman's lunch...
# Processing the postman...
# Processing the power of one...
# Processing the princess bride...
# Processing the private life of sherlock holmes...
# Processing the producer...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the producers...
# Processing the program...
# Processing the prophecy...
# Processing the proposal...
# Processing the queen...
# Processing the reader...
# Processing the relic...
# Processing the replacements...
# Processing the road...
# Processing the road warrior...
# Processing the rock...
# Processing the rocky horror picture show...
# Processing the ruins...
# Processing the saint...
# Processing the salton sea...
# Processing the sandlot kids...
# Processing the scarlet letter...
# Processing the searchers...
# Processing the seventh seal...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the seventh victim...
# Processing the shawshank redemption...
# Processing the shining...
# Processing the shipping news...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the siege...
# Processing the sixth sense...
# Processing the sting...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the stuntman...
# Processing the surfer king...
# Processing the sweet hereafter...
# Processing the thin man...
# Processing the thing...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the third man...
# Processing the three musketeers...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the time machine...
# Processing the tourist...
# Processing the truman show...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the usual suspects...
# Processing the verdict...
# Processing the visitor...
# Processing the wedding date...
# Processing the white ribbon...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the wild bunch...
# Processing the witching hour...
# Processing the wizard of oz...
# Processing the woodsman...
# Processing the world is not enough...
# Processing the wrestler...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the x files...
# Processing the x files fight the future...
# Processing thelma & louise...
# Processing there's something about mary...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing thirteen days...
# Processing this boy's life...
# Processing three kings...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing three kings (spoils of war)...
# Processing three men and a baby...
# Processing thunderheart...
# Processing thx 1138...
# Processing ticker...
# Processing timber falls...
# Processing tin cup...
# Processing tin men...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing titanic...
# Processing tmnt...
# Processing to sleep with anger...
# Processing tombstone...
# Processing tomorrow never dies...
# Processing top gun...
# Processing total recall...
# Processing toy story...
# Processing traffic...
# Processing trainspotting...
# Processing transatlantic merry-go-round...
# Processing transformers the movie...
# Processing tremors...
# Processing tristan and isolde...
# Processing tron...
# Processing tropic thunder...
# Processing trouble in paradise...
# Processing true believer...
# Processing true lies...
# Processing true romance...
# Processing twelve monkeys...
# Processing twilight...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing twilight new moon...
# Processing twin peaks...
# Processing twin peaks: fire walk with me...
# Processing twins...
# Processing two for the money...
# Processing u turn...
# Processing u-turn...
# Processing unbreakable...
# Processing under fire...
# Processing unforgiven...
# Processing up...
# Processing up in the air...
# Processing v for vendetta...
# Processing valkyrie...
# Processing vampyr...
# Processing vanilla sky...
# Processing vertigo...
# Processing very bad things...
# Processing village...
# Processing viridiana...
# Processing virtuosity...
# Processing wag the dog...
# Processing walking tall...
# Processing wall e...
# Processing wall street...
# Processing wanted...
# Processing war of the worlds...
# Processing warm springs...
# Processing watchmen...
# Processing waxwork...
# Processing we own the night...
# Processing what about bob%3f...
# Processing what lies beneath...
# Processing what women want...
# Processing when a stranger calls...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing while she was out...
# Processing white angel...
# Processing white christmas...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing white jazz...
# Processing white squall...
# Processing whiteout...
# Processing who framed roger rabbit...
# Processing who framed roger rabbit%3f...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing who's your daddy...
# Processing wild at heart...
# Processing wild things...
# Processing wild things diamonds in the rough...
# Processing wild wild west...
# Processing willow...
# Processing wind chill...
# Processing withnail and i...
# Processing witness...
# Processing wonder boys...
# Processing x men...
# Processing x men origins wolverine...
# Processing x-men...
# Processing xxx...
# Processing year one...
# Processing yes man...
# Processing you can count on me...
# Processing you've got mail...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing young frankenstein...
# Processing youth in revolt...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing zerophilia...
# Processing zulu dawn...
# CPU times: user 3min 33s, sys: 6.25 s, total: 3min 39s
# Wall time: 3h 30min 56s

# %%
movie_info.to_csv('../data/movie_info_rough.csv', index_label= False)

# %% [markdown]
# Observing unprocessed information:

# %%
# If there are no nulls accross the columns for each row, then all the information is collected
movie_info.loc[~movie_info.isnull().any(axis=1),'info_all_collected'] = 1

# %% [markdown]
# There are 114 unprocessed movie titles, I will attempt to run them through the function again.

# %%
len(movie_info[movie_info['info_all_collected'] ==0])
# Out:
# 114

# %%
unprocessed_mov = movie_info[movie_info['info_all_collected'] ==0]['original_title']

# %%
# %%time
for row_index, title in unprocessed_mov.iteritems():
    movie_info_update(movie_info, row_index, title)
# Out:
# Processing a nightmare on elm street part 2: freddy's revenge...
# Processing a walk to remember...
# Processing ali...
# Processing all the president's men...
# Processing antitrust...
# Processing antz...
# Processing arctic blue...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing babel...
# Processing basic instinct...
# Processing beloved...
# Processing bridesmaids...
# Processing bringing out the dead...
# Processing catch me if you can...
# Processing chaos...
# Processing cinema paradiso...
# Processing cold mountain...
# Processing crouching tiger, hidden dragon...
# Processing cube...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing darkman...
# Processing deception...
# Processing die hard...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing dogma...
# Processing double indemnity...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing entrapment...
# Processing extract...
# Processing fight club...
# Processing four rooms...
# Processing g...
# Processing grand hotel...
# Processing hanna...
# Processing heist...
# Processing hellboy...
# Processing hellboy 2 the golden army...
# Processing hider in the house...
# Processing hostage...
# Processing how to train your dragon...
# Processing i am sam...
# Processing indiana jones iv...
# Processing jaws 2...
# Processing kill bill volume 1 & 2...
# Processing labor of love...
# Processing life...
# Processing lΘon...
# Processing made...
# Processing manhunter...
# Processing metropolis...
# Processing moonstruck...
# Processing murderland...
# Processing ocean's twelve...
# Processing pet sematary ii...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing pirates of the caribbean...
# Processing plastic man...
# Processing precious...
# Processing psycho...
# Processing quills...
# Processing raging bull...
# Processing s...
# Processing save the last dance...
# Processing seven...
# Processing sherlock holmes...
# Processing shivers...
# Processing shock treatment...
# Processing slash...
# Processing spare me...
# Processing spider-man...
# Processing star trek v: the final frontier...
# Processing star wars...
# Processing star wars attack of the clones...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing state and main...
# Processing suburbia...
# Processing sunshine cleaning...
# Processing terminator 2: judgment day...
# Processing terminator 2: judgment day - omitted scenes...
# Processing terminator salvation...
# Processing the abyss...
# Processing the big blue...
# Processing the book of eli...
# Processing the brothers bloom...
# Processing the cincinnati kid...
# Processing the crow salvation...
# Processing the curse...
# Processing the day the clown cried...
# Processing the exorcist...
# Processing the fifth element...
# Processing the ghost and the darkness...
# Processing the good girl...
# Processing the goonies 2...
# Processing the hustler...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the insider...
# Processing the island...
# Processing the last boy scout...
# Processing the leopard man...
# Processing the limey...
# Processing the matrix...
# Processing the matrix reloaded...
# Processing the producer...
# Processing the seventh seal...
# Processing the shipping news...
# Processing the sting...
# Processing the thing...
# Processing the three musketeers...
# Processing the truman show...
# Processing the white ribbon...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing the wrestler...
# Processing there's something about mary...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing three kings...
# Processing tin men...
# Processing twilight...
# Processing when a stranger calls...
# Processing white christmas...
# Processing white jazz...
# Processing who framed roger rabbit%3f...
# Processing you've got mail...
# Processing youth in revolt...
# CPU times: user 22.5 s, sys: 650 ms, total: 23.1 s
# Wall time: 13min 14s

# %%
# If there are no nulls accross the columns for each row, then all the information is collected
movie_info.loc[~movie_info.isnull().any(axis=1),'info_all_collected'] = 1

# %%
# Same process again:
unprocessed_mov = movie_info[(movie_info['info_all_collected'] ==0)&(movie_info['genre'].isnull())]['original_title']

# %%
# %%time
unprocessed_mov = movie_info[(movie_info['info_all_collected'] ==0)&(movie_info['genre'].isnull())]['original_title']
for row_index, title in unprocessed_mov.iteritems():
    movie_info_update(movie_info, row_index, title)
# Out:
# Processing arctic blue...
# Processing cube...
# Processing die hard...
# Processing double indemnity...
# Processing lΘon...
# Processing pet sematary ii...
# Processing pirates of the caribbean...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing star wars...
# Processing star wars attack of the clones...
# Processing the hustler...
# Processing the white ribbon...
# Failed to obtain IMDb url
# Failed to request IMDb url
# Processing there's something about mary...
# CPU times: user 2.74 s, sys: 67.4 ms, total: 2.8 s
# Wall time: 1min 24s

# %%
movie_info[movie_info.isnull().any(axis=1)].sort_values('genre')
# Out:
#                 original_title  \
# 613                plastic man
# 855              the goonies 2
# 1048                white jazz
# 466              labor of love
# 663                          s
# 721                   spare me
# 228                   die hard
# 500                       lΘon
# 610   pirates of the caribbean
# 740                  star wars
# 966           the white ribbon
#
#                                              imdb_title  \
# 613                                         Plastic Man
# 855                                       The Goonies 2
# 1048                                         White Jazz
# 466                                       Labor of Love
# 663                                            S (2015)
# 721                                     Spare Me (1993)
# 228                                     Die Hard Series
# 500                                        IMDb Top 250
# 610   pirates of the caribbean movie imdb - Google S...
# 740                         STAR WARS FILMS (1977-2015)
# 966         the white ribbon movie imdb - Google Search
#
#                                     imdb_url                genre pic_url  \
# 613    https://www.imdb.com/title/tt9411946/        Action,Sci-Fi     NaN
# 855    https://www.imdb.com/title/tt3652896/            Adventure     NaN
# 1048   https://www.imdb.com/title/tt0892384/  Crime,Drama,Mystery     NaN
# 466    https://www.imdb.com/title/tt1677731/        Drama,Mystery     NaN
# 663    https://www.imdb.com/title/tt4510636/          Short,Drama     NaN
# 721    https://www.imdb.com/title/tt0108200/             Thriller     NaN
# 228   https://www.imdb.com/list/ls057313912/                  NaN     NaN
# 500           https://www.imdb.com/chart/top                  NaN     NaN
# 610                                      NaN                  NaN     NaN
# 740   https://www.imdb.com/list/ls070150896/                  NaN     NaN
# 966                                      NaN                  NaN     NaN
#
#       info_all_collected
# 613                    0
# 855                    0
# 1048                   0
# 466                    0
# 663                    0
# 721                    0
# 228                    0
# 500                    0
# 610                    0
# 740                    0
# 966                    0

# %% [markdown]
# Manually filling `pic_url`'s for lesser known movies that do not have photos on imdb:

# %%
movie_info.at[613,'pic_url'] = 'https://m.media-amazon.com/images/M/MV5BZWQ1ZjdkNWYtZTgwNS00MzNiLWExYWEtMWE3NzgwNmYxNTU1XkEyXkFqcGdeQXVyNjExODE1MDc@._V1_.jpg'
movie_info.at[855,'pic_url'] = 'https://cdn3.movieweb.com/i/article/vNfany1Ej6mA3nCrWmVDnabqEQSdjG/798:50/Goonies-2-Wont-Happen-Richard-Donner-Old-Age.jpg'
movie_info.at[1048,'pic_url'] = 'http://r72.cooltext.com/rendered/cooltext324247263286443.gif'
movie_info.at[466,'pic_url'] = 'https://www.ethanproductions.com/movies-newDB/images/402540600007.jpg'
movie_info.at[663,'pic_url'] = 'https://www.timelesswroughtiron.com/v/vspfiles/photos/UGHT-IRON-HOUSE-LETTER-S-LET-S-2T.jpg'
movie_info.at[721,'pic_url'] = 'https://upload.wikimedia.org/wikipedia/en/thumb/e/e3/Video.SM.jpg/220px-Video.SM.jpg'

# %%
movie_info[movie_info.isnull().any(axis=1)]
# Out:
#                original_title  \
# 228                  die hard
# 500                      lΘon
# 610  pirates of the caribbean
# 740                 star wars
# 966          the white ribbon
#
#                                             imdb_title  \
# 228                                    Die Hard Series
# 500                                       IMDb Top 250
# 610  pirates of the caribbean movie imdb - Google S...
# 740                        STAR WARS FILMS (1977-2015)
# 966        the white ribbon movie imdb - Google Search
#
#                                    imdb_url genre pic_url  info_all_collected
# 228  https://www.imdb.com/list/ls057313912/   NaN     NaN                   0
# 500          https://www.imdb.com/chart/top   NaN     NaN                   0
# 610                                     NaN   NaN     NaN                   0
# 740  https://www.imdb.com/list/ls070150896/   NaN     NaN                   0
# 966                                     NaN   NaN     NaN                   0

# %%
movie_info.loc[~movie_info.isnull().any(axis=1),'info_all_collected'] = 1

# %%
# %%time
unprocessed_mov = movie_info[movie_info['info_all_collected'] == 0]['original_title']
print(unprocessed_mov)
for row_index, title in unprocessed_mov.iteritems():
    movie_info_update(movie_info, row_index, title)
# Out:
# 228                    die hard
# 500                        lΘon
# 610    pirates of the caribbean
# 740                   star wars
# 966            the white ribbon
# Name: original_title, dtype: object
# Processing die hard...
# Processing lΘon...
# Processing pirates of the caribbean...
# Processing star wars...
# Processing the white ribbon...
# CPU times: user 1.75 s, sys: 855 ms, total: 2.6 s
# Wall time: 35.3 s

# %%
movie_info[movie_info['info_all_collected'] == 0]
# Out:
#                original_title                            imdb_title  \
# 228                  die hard                       Die Hard Series
# 500                      lΘon                          IMDb Top 250
# 610  pirates of the caribbean  Pirates of the Caribbean Film Series
# 740                 star wars           STAR WARS FILMS (1977-2015)
#
#                                    imdb_url genre pic_url  info_all_collected
# 228  https://www.imdb.com/list/ls057313912/   NaN     NaN                   0
# 500          https://www.imdb.com/chart/top   NaN     NaN                   0
# 610  https://www.imdb.com/list/ls059602270/   NaN     NaN                   0
# 740  https://www.imdb.com/list/ls070150896/   NaN     NaN                   0

# %% [markdown]
# Manually changing the last four movies' information.
# I will first rename 'lΘon' to 'leon the professional' in both dataframes, `movie_info` and `mov_combo`.

# %%
mov_combo.loc[mov_combo[mov_combo['title'].str.contains('lΘon')].index,'title'] = 'leon the professional'

# %%
movie_info.loc[movie_info[movie_info['original_title'].str.contains('lΘon')].index,'original_title'] = 'leon the professional'

# %%
movie_info[movie_info['info_all_collected'] == 0]
# Out:
#                original_title                            imdb_title  \
# 228                  die hard                       Die Hard Series
# 500     leon the professional                          IMDb Top 250
# 610  pirates of the caribbean  Pirates of the Caribbean Film Series
# 740                 star wars           STAR WARS FILMS (1977-2015)
#
#                                    imdb_url genre pic_url  info_all_collected
# 228  https://www.imdb.com/list/ls057313912/   NaN     NaN                   0
# 500          https://www.imdb.com/chart/top   NaN     NaN                   0
# 610  https://www.imdb.com/list/ls059602270/   NaN     NaN                   0
# 740  https://www.imdb.com/list/ls070150896/   NaN     NaN                   0

# %%
movie_info_update(movie_info, 500, 'leon the professional')
# Out:
# Processing leon the professional...

# %%
movie_info[movie_info['info_all_collected'] == 0]
# Out:
#                original_title                            imdb_title  \
# 228                  die hard                       Die Hard Series
# 610  pirates of the caribbean  Pirates of the Caribbean Film Series
# 740                 star wars           STAR WARS FILMS (1977-2015)
#
#                                    imdb_url genre pic_url  info_all_collected
# 228  https://www.imdb.com/list/ls057313912/   NaN     NaN                   0
# 610  https://www.imdb.com/list/ls059602270/   NaN     NaN                   0
# 740  https://www.imdb.com/list/ls070150896/   NaN     NaN                   0

# %%
movie_info_update(movie_info, 228, 'die hard 1988')
movie_info_update(movie_info, 610, 'pirates of the caribbean black pearl')
movie_info_update(movie_info, 740, 'Star Wars episode iv')
# Out:
# Processing die hard 1988...
# Processing pirates of the caribbean black pearl...
# Processing Star Wars episode iv...

# %% [markdown]
# There are no nulls, huzzah!

# %%
movie_info[movie_info['info_all_collected'] == 0]
# Out:
# Empty DataFrame
# Columns: [original_title, imdb_title, imdb_url, genre, pic_url, info_all_collected]
# Index: []

# %%
movie_info.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# Looking for duplicate movies based on their `imdb_title`.

# %%
len(movie_info[movie_info.duplicated('imdb_title')].sort_values('imdb_title'))
# Out:
# 51

# %% [markdown]
# There are roughly 51 duplicated movie titles. Since the `original_title` column originally came from the `mov_combo` dataframe, I will merge the two dataframes together and then eliminate the duplicate movie titles, which may imply that there are duplicate movie characters per movie.

# %%
movie_info.to_csv('../data/movie_info.csv', index_label = False)

# %% [markdown]
# ## Merging `movie_info` and `mov_combo`
#
# I am going to merge the dataframes on their respective movie titles column. I first need to check whether their titles match correctly by taking the set difference of the movie titles.

# %%
# Number of movie titles are true
len(movie_info) == len(mov_combo['title'].unique())
# Out:
# True

# %%
set(movie_info['original_title']).difference(set(mov_combo['title'].unique()))
# Out:
# set()

# %% [markdown]
# An empty set indicates that I can go ahead and merge the dataframes together.

# %%
mov_combo_final  = mov_combo.merge(movie_info, left_on = 'title', right_on = 'original_title')

# %%
len(mov_combo_final['original_title'].unique())
# Out:
# 1075

# %% [markdown]
# There are several duplicate movies with slightly different `original_title` movie titles. I will remove one of the two duplicate movies whether it has a lower word count than the other.

# %%
#mov_combo_final.to_pickle('../data/mov_combo_final.pkl')

# %%
dups = movie_info[movie_info.duplicated('imdb_title',keep = False)].sort_values('imdb_title')
dups.head(6)
# Out:
#              original_title                      imdb_title  \
# 29    airplane 2 the sequel  Airplane II: The Sequel (1982)
# 30  airplane ii: the sequel  Airplane II: The Sequel (1982)
# 28                 airplane                Airplane! (1980)
# 31                airplane!                Airplane! (1980)
# 34                    alien                    Alien (1979)
# 38                 alien vs                    Alien (1979)
#
#                                  imdb_url          genre  \
# 29  https://www.imdb.com/title/tt0083530/  Comedy,Sci-Fi
# 30  https://www.imdb.com/title/tt0083530/  Comedy,Sci-Fi
# 28  https://www.imdb.com/title/tt0080339/         Comedy
# 31  https://www.imdb.com/title/tt0080339/         Comedy
# 34  https://www.imdb.com/title/tt0078748/  Horror,Sci-Fi
# 38  https://www.imdb.com/title/tt0078748/  Horror,Sci-Fi
#
#                                               pic_url  info_all_collected
# 29  https://m.media-amazon.com/images/M/MV5BMmVkYj...                   1
# 30  https://m.media-amazon.com/images/M/MV5BMmVkYj...                   1
# 28  https://m.media-amazon.com/images/M/MV5BZjA3Yj...                   1
# 31  https://m.media-amazon.com/images/M/MV5BZjA3Yj...                   1
# 34  https://m.media-amazon.com/images/M/MV5BMmQ2Mm...                   1
# 38  https://m.media-amazon.com/images/M/MV5BMmQ2Mm...                   1

# %%
dup_titles = list(dups['original_title'])

# creating a mask
for position, title in enumerate(dup_titles):
    quotes = '"'
    if position != len(dup_titles)-1:
        print(f"(mov_combo_final['original_title'] == {quotes}{title}{quotes})|")
    else:
        print(f"(mov_combo_final['original_title'] == {quotes}{title}{quotes})")
# Out:
# (mov_combo_final['original_title'] == "airplane 2 the sequel")|
# (mov_combo_final['original_title'] == "airplane ii: the sequel")|
# (mov_combo_final['original_title'] == "airplane")|
# (mov_combo_final['original_title'] == "airplane!")|
# (mov_combo_final['original_title'] == "alien")|
# (mov_combo_final['original_title'] == "alien vs")|
# (mov_combo_final['original_title'] == "american werewolf in london")|
# (mov_combo_final['original_title'] == "an american werewolf in london")|
# (mov_combo_final['original_title'] == "austin powers   international man of mystery")|
# (mov_combo_final['original_title'] == "austin powers: international man of mystery")|
# (mov_combo_final['original_title'] == "bachelor party")|
# (mov_combo_final['original_title'] == "the bachelor party")|
# (mov_combo_final['original_title'] == "beavis and butt-head do america")|
# (mov_combo_final['original_title'] == "beavis and butt head do america")|
# (mov_combo_final['original_title'] == "blast from the past")|
# (mov_combo_final['original_title'] == "the blast from the past")|
# (mov_combo_final['original_title'] == "cinema paradiso")|
# (mov_combo_final['original_title'] == "nuovo cinema paradiso")|
# (mov_combo_final['original_title'] == "crazy love")|
# (mov_combo_final['original_title'] == "crazylove")|
# (mov_combo_final['original_title'] == "dragon slayer")|
# (mov_combo_final['original_title'] == "dragonslayer")|
# (mov_combo_final['original_title'] == "ed tv")|
# (mov_combo_final['original_title'] == "edtv")|
# (mov_combo_final['original_title'] == "el mariachi")|
# (mov_combo_final['original_title'] == "mariachi, el")|
# (mov_combo_final['original_title'] == "evil dead ii dead by dawn")|
# (mov_combo_final['original_title'] == "evil dead 2: dead before dawn")|
# (mov_combo_final['original_title'] == "face/off")|
# (mov_combo_final['original_title'] == "face off")|
# (mov_combo_final['original_title'] == "ghostbusters 2")|
# (mov_combo_final['original_title'] == "ghostbusters ii")|
# (mov_combo_final['original_title'] == "glengarry glen gross")|
# (mov_combo_final['original_title'] == "glengarry glen ross")|
# (mov_combo_final['original_title'] == "gone in 60 seconds")|
# (mov_combo_final['original_title'] == "gone in sixty seconds")|
# (mov_combo_final['original_title'] == "grosse point blank")|
# (mov_combo_final['original_title'] == "grosse pointe blank")|
# (mov_combo_final['original_title'] == "halloween the curse of michael myers")|
# (mov_combo_final['original_title'] == "halloween: the curse of michael myers")|
# (mov_combo_final['original_title'] == "hellbound: hellraiser ii")|
# (mov_combo_final['original_title'] == "hellbound hellraiser ii")|
# (mov_combo_final['original_title'] == "hellraiser 3 hell on earth")|
# (mov_combo_final['original_title'] == "hellraiser iii: hell on earth")|
# (mov_combo_final['original_title'] == "interview with the vampire")|
# (mov_combo_final['original_title'] == "interview with the vampire: the vampire chronicles")|
# (mov_combo_final['original_title'] == "l'avventura")|
# (mov_combo_final['original_title'] == "avventura, l' (the adventure)")|
# (mov_combo_final['original_title'] == "love & basketball")|
# (mov_combo_final['original_title'] == "love and basketball")|
# (mov_combo_final['original_title'] == "leon the professional")|
# (mov_combo_final['original_title'] == "leon")|
# (mov_combo_final['original_title'] == "mighty morphin power rangers")|
# (mov_combo_final['original_title'] == "mighty morphin power rangers the movie")|
# (mov_combo_final['original_title'] == "o brother where art thou%3f")|
# (mov_combo_final['original_title'] == "o brother, where art thou?")|
# (mov_combo_final['original_title'] == "punch drunk love")|
# (mov_combo_final['original_title'] == "punch-drunk love")|
# (mov_combo_final['original_title'] == "rambo first blood ii the mission")|
# (mov_combo_final['original_title'] == "rambo: first blood part ii")|
# (mov_combo_final['original_title'] == "romeo & juliet")|
# (mov_combo_final['original_title'] == "romeo and juliet")|
# (mov_combo_final['original_title'] == "se7en")|
# (mov_combo_final['original_title'] == "seven")|
# (mov_combo_final['original_title'] == "south park")|
# (mov_combo_final['original_title'] == "south park: bigger longer & uncut")|
# (mov_combo_final['original_title'] == "spider man")|
# (mov_combo_final['original_title'] == "spider-man")|
# (mov_combo_final['original_title'] == "star trek ii the wrath of khan")|
# (mov_combo_final['original_title'] == "star trek: the wrath of khan")|
# (mov_combo_final['original_title'] == "star wars")|
# (mov_combo_final['original_title'] == "star wars a new hope")|
# (mov_combo_final['original_title'] == "star wars return of the jedi")|
# (mov_combo_final['original_title'] == "star wars: episode vi - return of the jedi")|
# (mov_combo_final['original_title'] == "sugar and spice")|
# (mov_combo_final['original_title'] == "sugar & spice")|
# (mov_combo_final['original_title'] == "terminator 2 judgement day")|
# (mov_combo_final['original_title'] == "terminator 2: judgment day")|
# (mov_combo_final['original_title'] == "terminator 2: judgment day - omitted scenes")|
# (mov_combo_final['original_title'] == "the adventures of buckaroo banzai across the 8th dimension")|
# (mov_combo_final['original_title'] == "the adventures of buckaroo banzai across the eighth dimension")|
# (mov_combo_final['original_title'] == "la battaglia di algeri")|
# (mov_combo_final['original_title'] == "the battle of algiers")|
# (mov_combo_final['original_title'] == "le grand bleu")|
# (mov_combo_final['original_title'] == "the big blue")|
# (mov_combo_final['original_title'] == "jurassic park the lost world")|
# (mov_combo_final['original_title'] == "the lost world: jurassic park")|
# (mov_combo_final['original_title'] == "the majestic (the bijou)")|
# (mov_combo_final['original_title'] == "the majestic")|
# (mov_combo_final['original_title'] == "the x files")|
# (mov_combo_final['original_title'] == "the x files fight the future")|
# (mov_combo_final['original_title'] == "three kings")|
# (mov_combo_final['original_title'] == "three kings (spoils of war)")|
# (mov_combo_final['original_title'] == "twin peaks")|
# (mov_combo_final['original_title'] == "twin peaks: fire walk with me")|
# (mov_combo_final['original_title'] == "u turn")|
# (mov_combo_final['original_title'] == "u-turn")|
# (mov_combo_final['original_title'] == "who framed roger rabbit")|
# (mov_combo_final['original_title'] == "who framed roger rabbit%3f")|
# (mov_combo_final['original_title'] == "x men")|
# (mov_combo_final['original_title'] == "x-men")

# %%
mov_combo_dup_title = mov_combo_final[
(mov_combo_final['original_title'] == "airplane 2 the sequel")|
(mov_combo_final['original_title'] == "airplane ii: the sequel")|
(mov_combo_final['original_title'] == "airplane")|
(mov_combo_final['original_title'] == "airplane!")|
(mov_combo_final['original_title'] == "alien")|
(mov_combo_final['original_title'] == "alien vs")|
(mov_combo_final['original_title'] == "american werewolf in london")|
(mov_combo_final['original_title'] == "an american werewolf in london")|
(mov_combo_final['original_title'] == "austin powers   international man of mystery")|
(mov_combo_final['original_title'] == "austin powers: international man of mystery")|
(mov_combo_final['original_title'] == "bachelor party")|
(mov_combo_final['original_title'] == "the bachelor party")|
(mov_combo_final['original_title'] == "beavis and butt-head do america")|
(mov_combo_final['original_title'] == "beavis and butt head do america")|
(mov_combo_final['original_title'] == "blast from the past")|
(mov_combo_final['original_title'] == "the blast from the past")|
(mov_combo_final['original_title'] == "cinema paradiso")|
(mov_combo_final['original_title'] == "nuovo cinema paradiso")|
(mov_combo_final['original_title'] == "crazy love")|
(mov_combo_final['original_title'] == "crazylove")|
(mov_combo_final['original_title'] == "dragon slayer")|
(mov_combo_final['original_title'] == "dragonslayer")|
(mov_combo_final['original_title'] == "ed tv")|
(mov_combo_final['original_title'] == "edtv")|
(mov_combo_final['original_title'] == "el mariachi")|
(mov_combo_final['original_title'] == "mariachi, el")|
(mov_combo_final['original_title'] == "evil dead ii dead by dawn")|
(mov_combo_final['original_title'] == "evil dead 2: dead before dawn")|
(mov_combo_final['original_title'] == "face/off")|
(mov_combo_final['original_title'] == "face off")|
(mov_combo_final['original_title'] == "ghostbusters 2")|
(mov_combo_final['original_title'] == "ghostbusters ii")|
(mov_combo_final['original_title'] == "glengarry glen gross")|
(mov_combo_final['original_title'] == "glengarry glen ross")|
(mov_combo_final['original_title'] == "gone in 60 seconds")|
(mov_combo_final['original_title'] == "gone in sixty seconds")|
(mov_combo_final['original_title'] == "grosse point blank")|
(mov_combo_final['original_title'] == "grosse pointe blank")|
(mov_combo_final['original_title'] == "halloween the curse of michael myers")|
(mov_combo_final['original_title'] == "halloween: the curse of michael myers")|
(mov_combo_final['original_title'] == "hellbound: hellraiser ii")|
(mov_combo_final['original_title'] == "hellbound hellraiser ii")|
(mov_combo_final['original_title'] == "hellraiser 3 hell on earth")|
(mov_combo_final['original_title'] == "hellraiser iii: hell on earth")|
(mov_combo_final['original_title'] == "interview with the vampire")|
(mov_combo_final['original_title'] == "interview with the vampire: the vampire chronicles")|
(mov_combo_final['original_title'] == "l'avventura")|
(mov_combo_final['original_title'] == "avventura, l' (the adventure)")|
(mov_combo_final['original_title'] == "love & basketball")|
(mov_combo_final['original_title'] == "love and basketball")|
(mov_combo_final['original_title'] == "leon the professional")|
(mov_combo_final['original_title'] == "leon")|
(mov_combo_final['original_title'] == "mighty morphin power rangers")|
(mov_combo_final['original_title'] == "mighty morphin power rangers the movie")|
(mov_combo_final['original_title'] == "o brother where art thou%3f")|
(mov_combo_final['original_title'] == "o brother, where art thou?")|
(mov_combo_final['original_title'] == "punch drunk love")|
(mov_combo_final['original_title'] == "punch-drunk love")|
(mov_combo_final['original_title'] == "rambo first blood ii the mission")|
(mov_combo_final['original_title'] == "rambo: first blood part ii")|
(mov_combo_final['original_title'] == "romeo & juliet")|
(mov_combo_final['original_title'] == "romeo and juliet")|
(mov_combo_final['original_title'] == "se7en")|
(mov_combo_final['original_title'] == "seven")|
(mov_combo_final['original_title'] == "south park")|
(mov_combo_final['original_title'] == "south park: bigger longer & uncut")|
(mov_combo_final['original_title'] == "spider man")|
(mov_combo_final['original_title'] == "spider-man")|
(mov_combo_final['original_title'] == "star trek ii the wrath of khan")|
(mov_combo_final['original_title'] == "star trek: the wrath of khan")|
(mov_combo_final['original_title'] == "star wars")|
(mov_combo_final['original_title'] == "star wars a new hope")|
(mov_combo_final['original_title'] == "star wars return of the jedi")|
(mov_combo_final['original_title'] == "star wars: episode vi - return of the jedi")|
(mov_combo_final['original_title'] == "sugar and spice")|
(mov_combo_final['original_title'] == "sugar & spice")|
(mov_combo_final['original_title'] == "terminator 2 judgement day")|
(mov_combo_final['original_title'] == "terminator 2: judgment day")|
(mov_combo_final['original_title'] == "terminator 2: judgment day - omitted scenes")|
(mov_combo_final['original_title'] == "the adventures of buckaroo banzai across the 8th dimension")|
(mov_combo_final['original_title'] == "the adventures of buckaroo banzai across the eighth dimension")|
(mov_combo_final['original_title'] == "la battaglia di algeri")|
(mov_combo_final['original_title'] == "the battle of algiers")|
(mov_combo_final['original_title'] == "le grand bleu")|
(mov_combo_final['original_title'] == "the big blue")|
(mov_combo_final['original_title'] == "jurassic park the lost world")|
(mov_combo_final['original_title'] == "the lost world: jurassic park")|
(mov_combo_final['original_title'] == "the majestic (the bijou)")|
(mov_combo_final['original_title'] == "the majestic")|
(mov_combo_final['original_title'] == "the x files")|
(mov_combo_final['original_title'] == "the x files fight the future")|
(mov_combo_final['original_title'] == "three kings")|
(mov_combo_final['original_title'] == "three kings (spoils of war)")|
(mov_combo_final['original_title'] == "twin peaks")|
(mov_combo_final['original_title'] == "twin peaks: fire walk with me")|
(mov_combo_final['original_title'] == "u turn")|
(mov_combo_final['original_title'] == "u-turn")|
(mov_combo_final['original_title'] == "who framed roger rabbit")|
(mov_combo_final['original_title'] == "who framed roger rabbit%3f")|
(mov_combo_final['original_title'] == "x men")|
(mov_combo_final['original_title'] == "x-men")]

# %%
title_wc = pd.DataFrame(mov_combo_dup_title.sort_values('original_title').groupby('original_title')['word_count'].sum())
title_wc = title_wc.reset_index()

# merging title_wc with movie_info to sort by imdb_title
title_wc  = title_wc.merge(movie_info[['original_title','imdb_title']], on = 'original_title')

# %% [markdown]
# I will now sort the `title_wc` dataframe by the movie title and the word count from smallest to largest.
# I will then extract the `original_title` movie titles that have a fewer word count to remove them from the `mov_combo_final` dataframe.

# %%
title_wc = title_wc.sort_values(['imdb_title','word_count'], ascending = True)

title_wc.head(8)
# Out:
#                    original_title  word_count  \
# 1           airplane 2 the sequel        9025
# 2         airplane ii: the sequel        9180
# 3                       airplane!        2869
# 0                        airplane        7458
# 4                           alien        8559
# 5                        alien vs       12062
# 6     american werewolf in london        7364
# 7  an american werewolf in london        7541
#
#                               imdb_title
# 1         Airplane II: The Sequel (1982)
# 2         Airplane II: The Sequel (1982)
# 3                       Airplane! (1980)
# 0                       Airplane! (1980)
# 4                           Alien (1979)
# 5                           Alien (1979)
# 6  An American Werewolf in London (1981)
# 7  An American Werewolf in London (1981)

# %%
movies_to_remove = list(title_wc.drop_duplicates(subset='imdb_title')['original_title'])

# %%
# creating a mask to remove the movies
for position, title in enumerate(movies_to_remove):
    quotes = '"'
    if position != len(movies_to_remove)-1:
        print(f"(mov_combo_final['original_title'] != {quotes}{title}{quotes})&")
    else:
        print(f"(mov_combo_final['original_title'] != {quotes}{title}{quotes})")
# Out:
# (mov_combo_final['original_title'] != "airplane 2 the sequel")&
# (mov_combo_final['original_title'] != "airplane!")&
# (mov_combo_final['original_title'] != "alien")&
# (mov_combo_final['original_title'] != "american werewolf in london")&
# (mov_combo_final['original_title'] != "austin powers   international man of mystery")&
# (mov_combo_final['original_title'] != "bachelor party")&
# (mov_combo_final['original_title'] != "beavis and butt-head do america")&
# (mov_combo_final['original_title'] != "blast from the past")&
# (mov_combo_final['original_title'] != "nuovo cinema paradiso")&
# (mov_combo_final['original_title'] != "crazy love")&
# (mov_combo_final['original_title'] != "dragon slayer")&
# (mov_combo_final['original_title'] != "edtv")&
# (mov_combo_final['original_title'] != "el mariachi")&
# (mov_combo_final['original_title'] != "evil dead ii dead by dawn")&
# (mov_combo_final['original_title'] != "face/off")&
# (mov_combo_final['original_title'] != "ghostbusters ii")&
# (mov_combo_final['original_title'] != "glengarry glen gross")&
# (mov_combo_final['original_title'] != "gone in sixty seconds")&
# (mov_combo_final['original_title'] != "grosse point blank")&
# (mov_combo_final['original_title'] != "halloween: the curse of michael myers")&
# (mov_combo_final['original_title'] != "hellbound: hellraiser ii")&
# (mov_combo_final['original_title'] != "hellraiser 3 hell on earth")&
# (mov_combo_final['original_title'] != "interview with the vampire")&
# (mov_combo_final['original_title'] != "l'avventura")&
# (mov_combo_final['original_title'] != "love & basketball")&
# (mov_combo_final['original_title'] != "leon the professional")&
# (mov_combo_final['original_title'] != "mighty morphin power rangers the movie")&
# (mov_combo_final['original_title'] != "o brother where art thou%3f")&
# (mov_combo_final['original_title'] != "punch drunk love")&
# (mov_combo_final['original_title'] != "rambo: first blood part ii")&
# (mov_combo_final['original_title'] != "romeo and juliet")&
# (mov_combo_final['original_title'] != "seven")&
# (mov_combo_final['original_title'] != "south park: bigger longer & uncut")&
# (mov_combo_final['original_title'] != "spider-man")&
# (mov_combo_final['original_title'] != "star trek: the wrath of khan")&
# (mov_combo_final['original_title'] != "star wars")&
# (mov_combo_final['original_title'] != "star wars: episode vi - return of the jedi")&
# (mov_combo_final['original_title'] != "sugar and spice")&
# (mov_combo_final['original_title'] != "terminator 2: judgment day - omitted scenes")&
# (mov_combo_final['original_title'] != "the adventures of buckaroo banzai across the 8th dimension")&
# (mov_combo_final['original_title'] != "the battle of algiers")&
# (mov_combo_final['original_title'] != "le grand bleu")&
# (mov_combo_final['original_title'] != "jurassic park the lost world")&
# (mov_combo_final['original_title'] != "the majestic (the bijou)")&
# (mov_combo_final['original_title'] != "the x files fight the future")&
# (mov_combo_final['original_title'] != "three kings")&
# (mov_combo_final['original_title'] != "twin peaks")&
# (mov_combo_final['original_title'] != "u turn")&
# (mov_combo_final['original_title'] != "who framed roger rabbit%3f")&
# (mov_combo_final['original_title'] != "x-men")

# %%
mov_combo_final = mov_combo_final[(mov_combo_final['original_title'] != "airplane 2 the sequel")&
(mov_combo_final['original_title'] != "airplane!")&
(mov_combo_final['original_title'] != "alien")&
(mov_combo_final['original_title'] != "american werewolf in london")&
(mov_combo_final['original_title'] != "austin powers   international man of mystery")&
(mov_combo_final['original_title'] != "bachelor party")&
(mov_combo_final['original_title'] != "beavis and butt-head do america")&
(mov_combo_final['original_title'] != "blast from the past")&
(mov_combo_final['original_title'] != "nuovo cinema paradiso")&
(mov_combo_final['original_title'] != "crazy love")&
(mov_combo_final['original_title'] != "dragon slayer")&
(mov_combo_final['original_title'] != "edtv")&
(mov_combo_final['original_title'] != "el mariachi")&
(mov_combo_final['original_title'] != "evil dead ii dead by dawn")&
(mov_combo_final['original_title'] != "face/off")&
(mov_combo_final['original_title'] != "ghostbusters ii")&
(mov_combo_final['original_title'] != "glengarry glen gross")&
(mov_combo_final['original_title'] != "gone in sixty seconds")&
(mov_combo_final['original_title'] != "grosse point blank")&
(mov_combo_final['original_title'] != "halloween: the curse of michael myers")&
(mov_combo_final['original_title'] != "hellbound: hellraiser ii")&
(mov_combo_final['original_title'] != "hellraiser 3 hell on earth")&
(mov_combo_final['original_title'] != "interview with the vampire")&
(mov_combo_final['original_title'] != "l'avventura")&
(mov_combo_final['original_title'] != "love & basketball")&
(mov_combo_final['original_title'] != "leon the professional")&
(mov_combo_final['original_title'] != "mighty morphin power rangers the movie")&
(mov_combo_final['original_title'] != "o brother where art thou%3f")&
(mov_combo_final['original_title'] != "punch drunk love")&
(mov_combo_final['original_title'] != "rambo: first blood part ii")&
(mov_combo_final['original_title'] != "romeo and juliet")&
(mov_combo_final['original_title'] != "seven")&
(mov_combo_final['original_title'] != "south park: bigger longer & uncut")&
(mov_combo_final['original_title'] != "spider-man")&
(mov_combo_final['original_title'] != "star trek: the wrath of khan")&
(mov_combo_final['original_title'] != "star wars")&
(mov_combo_final['original_title'] != "star wars: episode vi - return of the jedi")&
(mov_combo_final['original_title'] != "sugar and spice")&
(mov_combo_final['original_title'] != "terminator 2: judgment day - omitted scenes")&
(mov_combo_final['original_title'] != "the adventures of buckaroo banzai across the 8th dimension")&
(mov_combo_final['original_title'] != "the battle of algiers")&
(mov_combo_final['original_title'] != "le grand bleu")&
(mov_combo_final['original_title'] != "jurassic park the lost world")&
(mov_combo_final['original_title'] != "the majestic (the bijou)")&
(mov_combo_final['original_title'] != "the x files fight the future")&
(mov_combo_final['original_title'] != "three kings")&
(mov_combo_final['original_title'] != "twin peaks")&
(mov_combo_final['original_title'] != "u turn")&
(mov_combo_final['original_title'] != "who framed roger rabbit%3f")&
(mov_combo_final['original_title'] != "x-men")]

# %%
mov_combo_final.reset_index(drop=True,inplace=True)

# %% [markdown]
# Dropping unnecessary columns, `info_all_collected`, `original_title`, and `title`, because I already have all of the information collected for each observation, and I have the official IMDb movie titles.

# %%
# Dropping mov_combo_final's info all collected
mov_combo_final['info_all_collected'].value_counts()
# Out:
# 1    77400
# Name: info_all_collected, dtype: int64

# %%
# title 
(mov_combo_final['title'] != mov_combo_final['original_title']).sum()
# Out:
# 0

# %%
mov_combo_final = mov_combo_final.drop(['info_all_collected','title'], 1)
mov_combo_final.reset_index(drop=True,inplace=True)

# %%
mov_combo_final = mov_combo_final.drop(['original_title'], 1)

# %% [markdown]
# Changing `genre` values into lists for EDA purposes.

# %%
mov_combo_final['genre'] = mov_combo_final['genre'].map(lambda x: x.split(','))

# %% [markdown]
# Rearranging the columns

# %%
mov_combo_final = mov_combo_final[['imdb_title', 'character','text','tokenized_text','word_count','vader','genre','imdb_url','pic_url']]

# %% [markdown]
# Deleting characters that have 0 words in their lines.

# %%
len(mov_combo_final[mov_combo_final['word_count'] == 0])
# Out:
# 1273

# %%
mov_combo_final = mov_combo_final[mov_combo_final['word_count']>0]
mov_combo_final.reset_index(drop=True,inplace=True)

# %% [markdown]
# Saving the `mov_combo_final` as a pickle to preserve dictionaries and lists within the dataframe. Also saving the `movie_info` dataframe as a csv.

# %%
mov_combo_final.to_pickle('../data/mov_combo_final.pkl')
movie_info.to_csv('../data/movie_info.csv', index_label = False)

# %% [markdown]
# # Proceed to Notebook 3: EDA
#
# Now that the `mov_combo_final` is cleaned up and ready to go, I will explore different trends in the movie lines.
